# %%
import pandas as pd
import numpy as np

# %%
combined_pitchers_df = pd.read_csv('../data/top_129_pitchers.csv')

# %%
combined_pitchers_df.shape
# Out:
# (282970, 93)

# %%
combined_pitchers_df.columns
# Out:
# Index(['Unnamed: 0', 'pitch_type', 'game_date', 'release_speed',
#        'release_pos_x', 'release_pos_z', 'player_name', 'batter', 'pitcher',
#        'events', 'description', 'spin_dir', 'spin_rate_deprecated',
#        'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des',
#        'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
#        'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x',
#        'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b',
#        'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
#        'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id',
#        'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
#        'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
#        'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1',
#        'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6',
#        'fielder_7', 'fielder_8', 'fielder_9', 'release_pos_y',
#        'estimated_ba_using_speedangle', 'estimated_woba_using_speedangle',
#        'woba_value', 'woba_denom', 'babip_value', 'iso_value',
#        'launch_speed_angle', 'at_bat_number', 'pitch_number', 'pitch_name',
#        'home_score', 'away_score', 'bat_score', 'fld_score', 'post_away_score',
#        'post_home_score', 'post_bat_score', 'post_fld_score',
#        'if_fielding_alignment', 'of_fielding_alignment', 'spin_axis',
#        'delta_home_win_exp', 'delta_run_exp'],
#       dtype='object')

# %%
selected_cols = ['game_date', 'player_name', 'pitcher', 'batter', 'stand', 'pitch_type', 'pitch_name', 'description', 
                 'zone', 'balls', 'strikes', 'inning', 'pitch_number', 'home_score', 'away_score', 'outs_when_up', 'events']

comb_pitchers_clean = combined_pitchers_df[selected_cols]

# %%
comb_pitchers_clean.isna().sum(axis=0)
# Out:
# game_date            0
# player_name          0
# pitcher              0
# batter               0
# stand                0
# pitch_type          96
# pitch_name          96
# description          0
# zone                98
# balls                0
# strikes              0
# inning               0
# pitch_number         0
# home_score           0
# away_score           0
# outs_when_up         0
# events          210473
# dtype: int64

# %%
comb_pitchers_clean.isna().any(axis=1)
# Out:
# 0         False
# 1         False
# 2          True
# 3          True
# 4          True
#           ...
# 282965     True
# 282966     True
# 282967     True
# 282968     True
# 282969     True
# Length: 282970, dtype: bool

# %%
comb_pitchers_clean[comb_pitchers_clean['pitch_type'].isna()]
# Out:
#          game_date        player_name  pitcher  batter stand pitch_type  \
# 11404   2023-04-22    Valdez, Framber   664285  663586     R        NaN
# 11405   2023-04-22    Valdez, Framber   664285  663586     R        NaN
# 99471   2023-05-16  Lorenzen, Michael   547179  668804     L        NaN
# 238107  2023-07-25   Canning, Griffin   656288  681481     L        NaN
# 238108  2023-07-25   Canning, Griffin   656288  681481     L        NaN
# ...            ...                ...      ...     ...   ...        ...
# 238195  2023-07-25   Canning, Griffin   656288  656716     L        NaN
# 238196  2023-07-25   Canning, Griffin   656288  656716     L        NaN
# 238197  2023-07-25   Canning, Griffin   656288  656716     L        NaN
# 238198  2023-07-25   Canning, Griffin   656288  656716     L        NaN
# 238199  2023-07-25   Canning, Griffin   656288  656716     L        NaN
#
#        pitch_name    description  zone  balls  strikes  inning  pitch_number  \
# 11404         NaN  hit_into_play   NaN      1        1       4             3
# 11405         NaN       foul_tip   NaN      1        0       4             2
# 99471         NaN  called_strike   NaN      0        0       1             1
# 238107        NaN  hit_into_play   NaN      0        2       5             3
# 238108        NaN  called_strike   NaN      0        1       5             2
# ...           ...            ...   ...    ...      ...     ...           ...
# 238195        NaN  called_strike   NaN      3        1       1             5
# 238196        NaN           ball   NaN      2        1       1             4
# 238197        NaN  called_strike   NaN      2        0       1             3
# 238198        NaN           ball   NaN      1        0       1             2
# 238199        NaN           ball   NaN      0        0       1             1
#
#         home_score  away_score  outs_when_up     events
# 11404            0           0             1  field_out
# 11405            0           0             1        NaN
# 99471            0           0             1        NaN
# 238107           2           4             2  field_out
# 238108           2           4             2        NaN
# ...            ...         ...           ...        ...
# 238195           0           2             0        NaN
# 238196           0           2             0        NaN
# 238197           0           2             0        NaN
# 238198           0           2             0        NaN
# 238199           0           2             0        NaN
#
# [96 rows x 17 columns]

# %%
# create a Boolean mask for the rows to remove
mask = comb_pitchers_clean['pitcher'] == 656288

comb_pitchers_clean = comb_pitchers_clean[~mask]

comb_pitchers_clean
# Out:
#          game_date         player_name  pitcher  batter stand pitch_type  \
# 0       2023-09-29         Lynn, Lance   458681  642731     R         SI
# 1       2023-09-29         Lynn, Lance   458681  592626     L         FC
# 2       2023-09-29         Lynn, Lance   458681  592626     L         FF
# 3       2023-09-29         Lynn, Lance   458681  592626     L         FF
# 4       2023-09-29         Lynn, Lance   458681  592626     L         SI
# ...            ...                 ...      ...     ...   ...        ...
# 282965  2023-04-05  Rodriguez, Grayson   680570  543760     R         SL
# 282966  2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 282967  2023-04-05  Rodriguez, Grayson   680570  543760     R         SL
# 282968  2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 282969  2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
#
#              pitch_name    description  zone  balls  strikes  inning  \
# 0                Sinker  hit_into_play  11.0      0        0       6
# 1                Cutter           ball  11.0      3        2       6
# 2       4-Seam Fastball           foul   5.0      3        1       6
# 3       4-Seam Fastball  called_strike   1.0      3        0       6
# 4                Sinker           ball  13.0      2        0       6
# ...                 ...            ...   ...    ...      ...     ...
# 282965           Slider           ball  14.0      2        2       1
# 282966  4-Seam Fastball  called_strike   9.0      2        1       1
# 282967           Slider           ball  14.0      1        1       1
# 282968  4-Seam Fastball           foul   2.0      1        0       1
# 282969  4-Seam Fastball           ball  14.0      0        0       1
#
#         pitch_number  home_score  away_score  outs_when_up  \
# 0                  1           2           6             1
# 1                  6           2           6             1
# 2                  5           2           6             1
# 3                  4           2           6             1
# 4                  3           2           6             1
# ...              ...         ...         ...           ...
# 282965             5           0           0             0
# 282966             4           0           0             0
# 282967             3           0           0             0
# 282968             2           0           0             0
# 282969             1           0           0             0
#
#                            events
# 0       grounded_into_double_play
# 1                            walk
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 282965                        NaN
# 282966                        NaN
# 282967                        NaN
# 282968                        NaN
# 282969                        NaN
#
# [280793 rows x 17 columns]

# %%
comb_pitchers_clean.isna().sum(axis=0)
# Out:
# game_date            0
# player_name          0
# pitcher              0
# batter               0
# stand                0
# pitch_type           3
# pitch_name           3
# description          0
# zone                 5
# balls                0
# strikes              0
# inning               0
# pitch_number         0
# home_score           0
# away_score           0
# outs_when_up         0
# events          208831
# dtype: int64

# %%
comb_pitchers_clean[comb_pitchers_clean['pitch_type'].isna()]
# Out:
#         game_date        player_name  pitcher  batter stand pitch_type  \
# 11404  2023-04-22    Valdez, Framber   664285  663586     R        NaN
# 11405  2023-04-22    Valdez, Framber   664285  663586     R        NaN
# 99471  2023-05-16  Lorenzen, Michael   547179  668804     L        NaN
#
#       pitch_name    description  zone  balls  strikes  inning  pitch_number  \
# 11404        NaN  hit_into_play   NaN      1        1       4             3
# 11405        NaN       foul_tip   NaN      1        0       4             2
# 99471        NaN  called_strike   NaN      0        0       1             1
#
#        home_score  away_score  outs_when_up     events
# 11404           0           0             1  field_out
# 11405           0           0             1        NaN
# 99471           0           0             1        NaN

# %%
comb_pitchers_clean = comb_pitchers_clean.dropna(subset=['pitch_type', 'pitch_name', 'zone'])

# %%
comb_pitchers_clean.isna().sum(axis=0)
# Out:
# game_date            0
# player_name          0
# pitcher              0
# batter               0
# stand                0
# pitch_type           0
# pitch_name           0
# description          0
# zone                 0
# balls                0
# strikes              0
# inning               0
# pitch_number         0
# home_score           0
# away_score           0
# outs_when_up         0
# events          208827
# dtype: int64

# %%
comb_pitchers_clean = comb_pitchers_clean.iloc[::-1]
comb_pitchers_clean.reset_index(drop=True, inplace=True)

# %%
comb_pitchers_clean
# Out:
#          game_date         player_name  pitcher  batter stand pitch_type  \
# 0       2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 1       2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 2       2023-04-05  Rodriguez, Grayson   680570  543760     R         SL
# 3       2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 4       2023-04-05  Rodriguez, Grayson   680570  543760     R         SL
# ...            ...                 ...      ...     ...   ...        ...
# 280783  2023-09-29         Lynn, Lance   458681  592626     L         SI
# 280784  2023-09-29         Lynn, Lance   458681  592626     L         FF
# 280785  2023-09-29         Lynn, Lance   458681  592626     L         FF
# 280786  2023-09-29         Lynn, Lance   458681  592626     L         FC
# 280787  2023-09-29         Lynn, Lance   458681  642731     R         SI
#
#              pitch_name    description  zone  balls  strikes  inning  \
# 0       4-Seam Fastball           ball  14.0      0        0       1
# 1       4-Seam Fastball           foul   2.0      1        0       1
# 2                Slider           ball  14.0      1        1       1
# 3       4-Seam Fastball  called_strike   9.0      2        1       1
# 4                Slider           ball  14.0      2        2       1
# ...                 ...            ...   ...    ...      ...     ...
# 280783           Sinker           ball  13.0      2        0       6
# 280784  4-Seam Fastball  called_strike   1.0      3        0       6
# 280785  4-Seam Fastball           foul   5.0      3        1       6
# 280786           Cutter           ball  11.0      3        2       6
# 280787           Sinker  hit_into_play  11.0      0        0       6
#
#         pitch_number  home_score  away_score  outs_when_up  \
# 0                  1           0           0             0
# 1                  2           0           0             0
# 2                  3           0           0             0
# 3                  4           0           0             0
# 4                  5           0           0             0
# ...              ...         ...         ...           ...
# 280783             3           2           6             1
# 280784             4           2           6             1
# 280785             5           2           6             1
# 280786             6           2           6             1
# 280787             1           2           6             1
#
#                            events
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 280783                        NaN
# 280784                        NaN
# 280785                        NaN
# 280786                       walk
# 280787  grounded_into_double_play
#
# [280788 rows x 17 columns]

# %%
def create_sequence_id_at_bat_ordered(df, num_pitches=3):
    """
    Create a 'sequence id' column in the DataFrame that contains information about the previous
    `num_pitches` pitches in the at-bat for the same batter, in chronological order. The information 
    includes Count, Pitch type, Location, and Result. If the at-bat has had fewer than `num_pitches`, 
    return 0.

    Args:
    df (DataFrame): The baseball data DataFrame.
    num_pitches (int): Number of previous pitches to include in the sequence.

    Returns:
    DataFrame: Modified DataFrame with the 'sequence id' column.
    """
    # Initialize a new column for the sequence id
    df['sequence_id'] = None

    # Iterate through the DataFrame
    for i in range(len(df)):
        # Initialize an empty list to store sequence information
        sequence_info = []
        current_batter = df.iloc[i]['batter']

        # Collect information from the previous `num_pitches` pitches for the same batter
        for j in range(1, num_pitches + 1):
            # Ensure we don't go out of bounds and the batter is the same
            if i - j >= 0 and df.iloc[i - j]['batter'] == current_batter:
                # Extract relevant information for the pitch
                pitch_info = df.iloc[i - j]
                count = str(pitch_info['balls']) + '-' + str(pitch_info['strikes'])
                pitch_type = pitch_info['pitch_type']
                result = pitch_info['description']

                # Create a string representation of the pitch information
                pitch_sequence = f"{count}_{pitch_type}_{result}"

                # Append to the sequence information list
                sequence_info.append(pitch_sequence)
            else:
                # If the at-bat has not had `num_pitches`, return 0
                sequence_info.append('0')
                break

        # Maintain chronological order of the sequence
        sequence_id_str = '|'.join(sequence_info)  # Keep the original order
        df.at[i, 'sequence_id'] = sequence_id_str

    return df

# Apply the function to create a sequence id based on at-bat history for the last three pitches
df_with_at_bat_sequence_ordered = create_sequence_id_at_bat_ordered(comb_pitchers_clean, num_pitches=3)

# Display the first few rows of the modified DataFrame
df_with_at_bat_sequence_ordered[['batter', 'sequence_id', 'balls', 'strikes', 'description']].head()
# Out:
#    batter                                   sequence_id  balls  strikes  \
# 0  543760                                             0      0        0
# 1  543760                                 0-0_FF_ball|0      1        0
# 2  543760                     1-0_FF_foul|0-0_FF_ball|0      1        1
# 3  543760           1-1_SL_ball|1-0_FF_foul|0-0_FF_ball      2        1
# 4  543760  2-1_FF_called_strike|1-1_SL_ball|1-0_FF_foul      2        2
#
#      description
# 0           ball
# 1           foul
# 2           ball
# 3  called_strike
# 4           ball

# %%
df_with_at_bat_sequence_ordered.head(50)
# Out:
#      game_date         player_name  pitcher  batter stand pitch_type  \
# 0   2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 1   2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 2   2023-04-05  Rodriguez, Grayson   680570  543760     R         SL
# 3   2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 4   2023-04-05  Rodriguez, Grayson   680570  543760     R         SL
# 5   2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 6   2023-04-05  Rodriguez, Grayson   680570  608369     L         FF
# 7   2023-04-05  Rodriguez, Grayson   680570  608369     L         CH
# 8   2023-04-05  Rodriguez, Grayson   680570  608369     L         CH
# 9   2023-04-05  Rodriguez, Grayson   680570  608369     L         FF
# 10  2023-04-05  Rodriguez, Grayson   680570  608369     L         CH
# 11  2023-04-05  Rodriguez, Grayson   680570  663993     L         FF
# 12  2023-04-05  Rodriguez, Grayson   680570  663993     L         CU
# 13  2023-04-05  Rodriguez, Grayson   680570  663993     L         FF
# 14  2023-04-05  Rodriguez, Grayson   680570  663993     L         FF
# 15  2023-04-05  Rodriguez, Grayson   680570  663993     L         FC
# 16  2023-04-05  Rodriguez, Grayson   680570  663993     L         SL
# 17  2023-04-05  Rodriguez, Grayson   680570  663993     L         CH
# 18  2023-04-05  Rodriguez, Grayson   680570  666969     R         FF
# 19  2023-04-05  Rodriguez, Grayson   680570  666969     R         SL
# 20  2023-04-05  Rodriguez, Grayson   680570  666969     R         SL
# 21  2023-04-05  Rodriguez, Grayson   680570  666969     R         SL
# 22  2023-04-05  Rodriguez, Grayson   680570  666969     R         FF
# 23  2023-04-05  Rodriguez, Grayson   680570  673962     R         SL
# 24  2023-04-05  Rodriguez, Grayson   680570  673962     R         FF
# 25  2023-04-05  Rodriguez, Grayson   680570  673962     R         SL
# 26  2023-04-05  Rodriguez, Grayson   680570  673962     R         CH
# 27  2023-04-05  Rodriguez, Grayson   680570  673962     R         CH
# 28  2023-04-05  Rodriguez, Grayson   680570  543257     L         FF
# 29  2023-04-05  Rodriguez, Grayson   680570  543257     L         FF
# 30  2023-04-05  Rodriguez, Grayson   680570  641598     R         FF
# 31  2023-04-05  Rodriguez, Grayson   680570  641598     R         FF
# 32  2023-04-05  Rodriguez, Grayson   680570  641598     R         FC
# 33  2023-04-05  Rodriguez, Grayson   680570  641680     L         FF
# 34  2023-04-05  Rodriguez, Grayson   680570  641680     L         FF
# 35  2023-04-05  Rodriguez, Grayson   680570  641680     L         FF
# 36  2023-04-05  Rodriguez, Grayson   680570  641680     L         FF
# 37  2023-04-05  Rodriguez, Grayson   680570  641680     L         CU
# 38  2023-04-05  Rodriguez, Grayson   680570  677649     R         SL
# 39  2023-04-05  Rodriguez, Grayson   680570  677649     R         FF
# 40  2023-04-05  Rodriguez, Grayson   680570  677649     R         SL
# 41  2023-04-05  Rodriguez, Grayson   680570  543760     R         SL
# 42  2023-04-05  Rodriguez, Grayson   680570  608369     L         CU
# 43  2023-04-05  Rodriguez, Grayson   680570  608369     L         FF
# 44  2023-04-05  Rodriguez, Grayson   680570  608369     L         FF
# 45  2023-04-05  Rodriguez, Grayson   680570  608369     L         FF
# 46  2023-04-05  Rodriguez, Grayson   680570  663993     L         FC
# 47  2023-04-05  Rodriguez, Grayson   680570  666969     R         FF
# 48  2023-04-05  Rodriguez, Grayson   680570  666969     R         SL
# 49  2023-04-05  Rodriguez, Grayson   680570  666969     R         SL
#
#          pitch_name              description  zone  balls  strikes  inning  \
# 0   4-Seam Fastball                     ball  14.0      0        0       1
# 1   4-Seam Fastball                     foul   2.0      1        0       1
# 2            Slider                     ball  14.0      1        1       1
# 3   4-Seam Fastball            called_strike   9.0      2        1       1
# 4            Slider                     ball  14.0      2        2       1
# 5   4-Seam Fastball                     ball  12.0      3        2       1
# 6   4-Seam Fastball            called_strike   4.0      0        0       1
# 7          Changeup                     ball  14.0      0        1       1
# 8          Changeup                     ball  14.0      1        1       1
# 9   4-Seam Fastball                     foul   3.0      2        1       1
# 10         Changeup            hit_into_play   5.0      2        2       1
# 11  4-Seam Fastball                     foul   1.0      0        0       1
# 12        Curveball            called_strike   6.0      0        1       1
# 13  4-Seam Fastball                     ball  12.0      0        2       1
# 14  4-Seam Fastball                     foul   2.0      1        2       1
# 15           Cutter                     ball  12.0      1        2       1
# 16           Slider                     foul   6.0      2        2       1
# 17         Changeup            hit_into_play   5.0      2        2       1
# 18  4-Seam Fastball                     foul  14.0      0        0       1
# 19           Slider                     ball  14.0      0        1       1
# 20           Slider          swinging_strike  14.0      1        1       1
# 21           Slider             blocked_ball  14.0      1        2       1
# 22  4-Seam Fastball            hit_into_play   5.0      2        2       1
# 23           Slider                     ball  14.0      0        0       1
# 24  4-Seam Fastball          swinging_strike   5.0      1        0       1
# 25           Slider                     ball  14.0      1        1       1
# 26         Changeup                     foul   5.0      2        1       1
# 27         Changeup            hit_into_play  14.0      2        2       1
# 28  4-Seam Fastball                     ball  14.0      0        0       1
# 29  4-Seam Fastball            hit_into_play   2.0      1        0       1
# 30  4-Seam Fastball                     ball  14.0      0        0       2
# 31  4-Seam Fastball                     ball   9.0      1        0       2
# 32           Cutter            hit_into_play   9.0      2        0       2
# 33  4-Seam Fastball            called_strike   4.0      0        0       2
# 34  4-Seam Fastball                     foul   5.0      0        1       2
# 35  4-Seam Fastball                     foul   2.0      0        2       2
# 36  4-Seam Fastball                     foul   2.0      0        2       2
# 37        Curveball            hit_into_play   3.0      0        2       2
# 38           Slider                 foul_tip   3.0      0        0       2
# 39  4-Seam Fastball          swinging_strike   1.0      0        1       2
# 40           Slider          swinging_strike  14.0      0        2       2
# 41           Slider            hit_into_play   8.0      0        0       3
# 42        Curveball  swinging_strike_blocked  14.0      0        0       3
# 43  4-Seam Fastball                     ball   8.0      0        1       3
# 44  4-Seam Fastball          swinging_strike   3.0      1        1       3
# 45  4-Seam Fastball          swinging_strike  11.0      1        2       3
# 46           Cutter            hit_into_play   6.0      0        0       3
# 47  4-Seam Fastball                     foul   5.0      0        0       3
# 48           Slider                     ball  14.0      0        1       3
# 49           Slider          swinging_strike  14.0      1        1       3
#
#     pitch_number  home_score  away_score  outs_when_up     events  \
# 0              1           0           0             0        NaN
# 1              2           0           0             0        NaN
# 2              3           0           0             0        NaN
# 3              4           0           0             0        NaN
# 4              5           0           0             0        NaN
# 5              6           0           0             0       walk
# 6              1           0           0             0        NaN
# 7              2           0           0             0        NaN
# 8              3           0           0             0        NaN
# 9              4           0           0             0        NaN
# 10             5           0           0             0  force_out
# 11             1           0           0             1        NaN
# 12             2           0           0             1        NaN
# 13             3           0           0             1        NaN
# 14             4           0           0             1        NaN
# 15             5           0           0             1        NaN
# 16             6           0           0             1        NaN
# 17             7           0           0             1  field_out
# 18             1           0           0             2        NaN
# 19             2           0           0             2        NaN
# 20             3           0           0             2        NaN
# 21             4           0           0             2        NaN
# 22             5           0           0             2     double
# 23             1           1           0             2        NaN
# 24             2           1           0             2        NaN
# 25             3           1           0             2        NaN
# 26             4           1           0             2        NaN
# 27             5           1           0             2     single
# 28             1           2           0             2        NaN
# 29             2           2           0             2  field_out
# 30             1           2           0             0        NaN
# 31             2           2           0             0        NaN
# 32             3           2           0             0  field_out
# 33             1           2           0             1        NaN
# 34             2           2           0             1        NaN
# 35             3           2           0             1        NaN
# 36             4           2           0             1        NaN
# 37             5           2           0             1  field_out
# 38             1           2           0             2        NaN
# 39             2           2           0             2        NaN
# 40             3           2           0             2  strikeout
# 41             1           2           0             0     single
# 42             1           2           0             0        NaN
# 43             2           2           0             0        NaN
# 44             3           2           0             0        NaN
# 45             4           2           0             0  strikeout
# 46             1           2           0             1  field_out
# 47             1           2           0             2        NaN
# 48             2           2           0             2        NaN
# 49             3           2           0             2        NaN
#
#                                           sequence_id
# 0                                                   0
# 1                                       0-0_FF_ball|0
# 2                           1-0_FF_foul|0-0_FF_ball|0
# 3                 1-1_SL_ball|1-0_FF_foul|0-0_FF_ball
# 4        2-1_FF_called_strike|1-1_SL_ball|1-0_FF_foul
# 5        2-2_SL_ball|2-1_FF_called_strike|1-1_SL_ball
# 6                                                   0
# 7                              0-0_FF_called_strike|0
# 8                  0-1_CH_ball|0-0_FF_called_strike|0
# 9        1-1_CH_ball|0-1_CH_ball|0-0_FF_called_strike
# 10                2-1_FF_foul|1-1_CH_ball|0-1_CH_ball
# 11                                                  0
# 12                                      0-0_FF_foul|0
# 13                 0-1_CU_called_strike|0-0_FF_foul|0
# 14       0-2_FF_ball|0-1_CU_called_strike|0-0_FF_foul
# 15       1-2_FF_foul|0-2_FF_ball|0-1_CU_called_strike
# 16                1-2_FC_ball|1-2_FF_foul|0-2_FF_ball
# 17                2-2_SL_foul|1-2_FC_ball|1-2_FF_foul
# 18                                                  0
# 19                                      0-0_FF_foul|0
# 20                          0-1_SL_ball|0-0_FF_foul|0
# 21     1-1_SL_swinging_strike|0-1_SL_ball|0-0_FF_foul
# 22  1-2_SL_blocked_ball|1-1_SL_swinging_strike|0-1...
# 23                                                  0
# 24                                      0-0_SL_ball|0
# 25               1-0_FF_swinging_strike|0-0_SL_ball|0
# 26     1-1_SL_ball|1-0_FF_swinging_strike|0-0_SL_ball
# 27     2-1_CH_foul|1-1_SL_ball|1-0_FF_swinging_strike
# 28                                                  0
# 29                                      0-0_FF_ball|0
# 30                                                  0
# 31                                      0-0_FF_ball|0
# 32                          1-0_FF_ball|0-0_FF_ball|0
# 33                                                  0
# 34                             0-0_FF_called_strike|0
# 35                 0-1_FF_foul|0-0_FF_called_strike|0
# 36       0-2_FF_foul|0-1_FF_foul|0-0_FF_called_strike
# 37                0-2_FF_foul|0-2_FF_foul|0-1_FF_foul
# 38                                                  0
# 39                                  0-0_SL_foul_tip|0
# 40           0-1_FF_swinging_strike|0-0_SL_foul_tip|0
# 41                                                  0
# 42                                                  0
# 43                   0-0_CU_swinging_strike_blocked|0
# 44       0-1_FF_ball|0-0_CU_swinging_strike_blocked|0
# 45  1-1_FF_swinging_strike|0-1_FF_ball|0-0_CU_swin...
# 46                                                  0
# 47                                                  0
# 48                                      0-0_FF_foul|0
# 49                          0-1_SL_ball|0-0_FF_foul|0

# %%
df_with_at_bat_sequence_ordered.shape
# Out:
# (280788, 18)

# %%
short_df = df_with_at_bat_sequence_ordered.loc[df_with_at_bat_sequence_ordered['player_name'] == 'Rodriguez, Grayson']

# %%
short_df.to_csv('short.csv')

# %%
df_with_at_bat_sequence_ordered['new_at_bat'] = df_with_at_bat_sequence_ordered['pitch_number'] == 1

# Grouping by game_date, batter, and the cumulative sum of new_at_bat (which increases with each new at-bat)
# Then, counting the number of unique at-bats for each batter in each game
at_bat_count = df_with_at_bat_sequence_ordered.groupby(['game_date', 'batter'])['new_at_bat'].sum().reset_index(name='at_bat_count')

df_with_at_bat_sequence_ordered['times_faced'] = df_with_at_bat_sequence_ordered.groupby(['game_date', 'batter'])['new_at_bat'].cumsum()

# %%
df_with_at_bat_sequence_ordered.drop(labels='new_at_bat', axis=1)
# Out:
#          game_date         player_name  pitcher  batter stand pitch_type  \
# 0       2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 1       2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 2       2023-04-05  Rodriguez, Grayson   680570  543760     R         SL
# 3       2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 4       2023-04-05  Rodriguez, Grayson   680570  543760     R         SL
# ...            ...                 ...      ...     ...   ...        ...
# 280783  2023-09-29         Lynn, Lance   458681  592626     L         SI
# 280784  2023-09-29         Lynn, Lance   458681  592626     L         FF
# 280785  2023-09-29         Lynn, Lance   458681  592626     L         FF
# 280786  2023-09-29         Lynn, Lance   458681  592626     L         FC
# 280787  2023-09-29         Lynn, Lance   458681  642731     R         SI
#
#              pitch_name    description  zone  balls  strikes  inning  \
# 0       4-Seam Fastball           ball  14.0      0        0       1
# 1       4-Seam Fastball           foul   2.0      1        0       1
# 2                Slider           ball  14.0      1        1       1
# 3       4-Seam Fastball  called_strike   9.0      2        1       1
# 4                Slider           ball  14.0      2        2       1
# ...                 ...            ...   ...    ...      ...     ...
# 280783           Sinker           ball  13.0      2        0       6
# 280784  4-Seam Fastball  called_strike   1.0      3        0       6
# 280785  4-Seam Fastball           foul   5.0      3        1       6
# 280786           Cutter           ball  11.0      3        2       6
# 280787           Sinker  hit_into_play  11.0      0        0       6
#
#         pitch_number  home_score  away_score  outs_when_up  \
# 0                  1           0           0             0
# 1                  2           0           0             0
# 2                  3           0           0             0
# 3                  4           0           0             0
# 4                  5           0           0             0
# ...              ...         ...         ...           ...
# 280783             3           2           6             1
# 280784             4           2           6             1
# 280785             5           2           6             1
# 280786             6           2           6             1
# 280787             1           2           6             1
#
#                            events  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 280783                        NaN
# 280784                        NaN
# 280785                        NaN
# 280786                       walk
# 280787  grounded_into_double_play
#
#                                          sequence_id  times_faced
# 0                                                  0            1
# 1                                      0-0_FF_ball|0            1
# 2                          1-0_FF_foul|0-0_FF_ball|0            1
# 3                1-1_SL_ball|1-0_FF_foul|0-0_FF_ball            1
# 4       2-1_FF_called_strike|1-1_SL_ball|1-0_FF_foul            1
# ...                                              ...          ...
# 280783                     1-0_FF_ball|0-0_SI_ball|0            3
# 280784           2-0_SI_ball|1-0_FF_ball|0-0_SI_ball            3
# 280785  3-0_FF_called_strike|2-0_SI_ball|1-0_FF_ball            3
# 280786  3-1_FF_foul|3-0_FF_called_strike|2-0_SI_ball            3
# 280787                                             0            3
#
# [280788 rows x 19 columns]

# %%
df_with_at_bat_sequence_ordered['events'].value_counts()
# Out:
# events
# field_out                     29122
# strikeout                     16344
# single                        10165
# walk                           5481
# double                         3325
# home_run                       2385
# grounded_into_double_play      1365
# force_out                      1271
# hit_by_pitch                    673
# field_error                     444
# sac_fly                         425
# triple                          275
# double_play                     150
# fielders_choice                 119
# sac_bunt                        115
# fielders_choice_out              89
# caught_stealing_2b               75
# strikeout_double_play            54
# catcher_interf                   42
# other_out                        11
# sac_fly_double_play               8
# pickoff_1b                        8
# pickoff_caught_stealing_2b        5
# caught_stealing_home              4
# caught_stealing_3b                3
# triple_play                       1
# pickoff_2b                        1
# pickoff_3b                        1
# Name: count, dtype: int64

# %%
df_with_at_bat_sequence_ordered
# Out:
#          game_date         player_name  pitcher  batter stand pitch_type  \
# 0       2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 1       2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 2       2023-04-05  Rodriguez, Grayson   680570  543760     R         SL
# 3       2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 4       2023-04-05  Rodriguez, Grayson   680570  543760     R         SL
# ...            ...                 ...      ...     ...   ...        ...
# 280783  2023-09-29         Lynn, Lance   458681  592626     L         SI
# 280784  2023-09-29         Lynn, Lance   458681  592626     L         FF
# 280785  2023-09-29         Lynn, Lance   458681  592626     L         FF
# 280786  2023-09-29         Lynn, Lance   458681  592626     L         FC
# 280787  2023-09-29         Lynn, Lance   458681  642731     R         SI
#
#              pitch_name    description  zone  balls  strikes  inning  \
# 0       4-Seam Fastball           ball  14.0      0        0       1
# 1       4-Seam Fastball           foul   2.0      1        0       1
# 2                Slider           ball  14.0      1        1       1
# 3       4-Seam Fastball  called_strike   9.0      2        1       1
# 4                Slider           ball  14.0      2        2       1
# ...                 ...            ...   ...    ...      ...     ...
# 280783           Sinker           ball  13.0      2        0       6
# 280784  4-Seam Fastball  called_strike   1.0      3        0       6
# 280785  4-Seam Fastball           foul   5.0      3        1       6
# 280786           Cutter           ball  11.0      3        2       6
# 280787           Sinker  hit_into_play  11.0      0        0       6
#
#         pitch_number  home_score  away_score  outs_when_up  \
# 0                  1           0           0             0
# 1                  2           0           0             0
# 2                  3           0           0             0
# 3                  4           0           0             0
# 4                  5           0           0             0
# ...              ...         ...         ...           ...
# 280783             3           2           6             1
# 280784             4           2           6             1
# 280785             5           2           6             1
# 280786             6           2           6             1
# 280787             1           2           6             1
#
#                            events  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 280783                        NaN
# 280784                        NaN
# 280785                        NaN
# 280786                       walk
# 280787  grounded_into_double_play
#
#                                          sequence_id  new_at_bat  times_faced
# 0                                                  0        True            1
# 1                                      0-0_FF_ball|0       False            1
# 2                          1-0_FF_foul|0-0_FF_ball|0       False            1
# 3                1-1_SL_ball|1-0_FF_foul|0-0_FF_ball       False            1
# 4       2-1_FF_called_strike|1-1_SL_ball|1-0_FF_foul       False            1
# ...                                              ...         ...          ...
# 280783                     1-0_FF_ball|0-0_SI_ball|0       False            3
# 280784           2-0_SI_ball|1-0_FF_ball|0-0_SI_ball       False            3
# 280785  3-0_FF_called_strike|2-0_SI_ball|1-0_FF_ball       False            3
# 280786  3-1_FF_foul|3-0_FF_called_strike|2-0_SI_ball       False            3
# 280787                                             0        True            3
#
# [280788 rows x 20 columns]

# %%
# Reimplementing the function with the correct approach

def mark_xbh_in_future_at_bats(df):
    # Flagging rows with extra base hits for each batter-pitcher combination
    df['extra_base_hit'] = df['events'].isin(['double', 'triple', 'home_run'])

    # Initializing the XBH column
    df['XBH'] = 0

    # Iterating through each unique game, batter, and pitcher combination
    for (game, batter, pitcher), group in df.groupby(['game_date', 'batter', 'pitcher']):
        # Check if there's an extra base hit in any of the at-bats
        if group['extra_base_hit'].any():
            # If yes, mark all future at-bats in the game for this batter-pitcher combination with a 1
            future_at_bats_index = group.index[group.index > group[group['extra_base_hit']].index[0]]
            df.loc[future_at_bats_index, 'XBH'] = 1

    return df

# Applying the function to the dataframe
df_with_at_bat_sequence_ordered = mark_xbh_in_future_at_bats(df_with_at_bat_sequence_ordered)

# Displaying the first few rows to verify the new column
df_with_at_bat_sequence_ordered[['game_date', 'batter', 'pitcher', 'events', 'XBH']].head()
# Out:
#     game_date  batter  pitcher events  XBH
# 0  2023-04-05  543760   680570    NaN    0
# 1  2023-04-05  543760   680570    NaN    0
# 2  2023-04-05  543760   680570    NaN    0
# 3  2023-04-05  543760   680570    NaN    0
# 4  2023-04-05  543760   680570    NaN    0

# %%
df_with_at_bat_sequence_ordered['large_score_dif'] = df_with_at_bat_sequence_ordered["home_score"] - df_with_at_bat_sequence_ordered["away_score"]

def check_diff(row):
    if abs(row["large_score_dif"]) >= 4:
        return 1
    else:
        return 0

df_with_at_bat_sequence_ordered["large_score_dif"] = df_with_at_bat_sequence_ordered.apply(check_diff, axis=1)

# %%
mask2 = df_with_at_bat_sequence_ordered['pitch_number'] <= 3

df_with_at_bat_sequence_ordered = df_with_at_bat_sequence_ordered[~mask2]

df_with_at_bat_sequence_ordered
# Out:
#          game_date         player_name  pitcher  batter stand pitch_type  \
# 3       2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 4       2023-04-05  Rodriguez, Grayson   680570  543760     R         SL
# 5       2023-04-05  Rodriguez, Grayson   680570  543760     R         FF
# 9       2023-04-05  Rodriguez, Grayson   680570  608369     L         FF
# 10      2023-04-05  Rodriguez, Grayson   680570  608369     L         CH
# ...            ...                 ...      ...     ...   ...        ...
# 280779  2023-09-29         Lynn, Lance   458681  527038     R         SL
# 280780  2023-09-29         Lynn, Lance   458681  527038     R         FC
# 280784  2023-09-29         Lynn, Lance   458681  592626     L         FF
# 280785  2023-09-29         Lynn, Lance   458681  592626     L         FF
# 280786  2023-09-29         Lynn, Lance   458681  592626     L         FC
#
#              pitch_name    description  zone  balls  ...  home_score  \
# 3       4-Seam Fastball  called_strike   9.0      2  ...           0
# 4                Slider           ball  14.0      2  ...           0
# 5       4-Seam Fastball           ball  12.0      3  ...           0
# 9       4-Seam Fastball           foul   3.0      2  ...           0
# 10             Changeup  hit_into_play   5.0      2  ...           0
# ...                 ...            ...   ...    ...  ...         ...
# 280779           Slider           ball  14.0      1  ...           2
# 280780           Cutter           ball  14.0      3  ...           2
# 280784  4-Seam Fastball  called_strike   1.0      3  ...           2
# 280785  4-Seam Fastball           foul   5.0      3  ...           2
# 280786           Cutter           ball  11.0      3  ...           2
#
#         away_score  outs_when_up     events  \
# 3                0             0        NaN
# 4                0             0        NaN
# 5                0             0       walk
# 9                0             0        NaN
# 10               0             0  force_out
# ...            ...           ...        ...
# 280779           6             1        NaN
# 280780           6             1       walk
# 280784           6             1        NaN
# 280785           6             1        NaN
# 280786           6             1       walk
#
#                                          sequence_id  new_at_bat times_faced  \
# 3                1-1_SL_ball|1-0_FF_foul|0-0_FF_ball       False           1
# 4       2-1_FF_called_strike|1-1_SL_ball|1-0_FF_foul       False           1
# 5       2-2_SL_ball|2-1_FF_called_strike|1-1_SL_ball       False           1
# 9       1-1_CH_ball|0-1_CH_ball|0-0_FF_called_strike       False           1
# 10               2-1_FF_foul|1-1_CH_ball|0-1_CH_ball       False           1
# ...                                              ...         ...         ...
# 280779  0-2_FF_ball|0-1_SL_foul|0-0_FC_called_strike       False           3
# 280780           1-2_SL_ball|0-2_FF_ball|0-1_SL_foul       False           3
# 280784           2-0_SI_ball|1-0_FF_ball|0-0_SI_ball       False           3
# 280785  3-0_FF_called_strike|2-0_SI_ball|1-0_FF_ball       False           3
# 280786  3-1_FF_foul|3-0_FF_called_strike|2-0_SI_ball       False           3
#
#        extra_base_hit  XBH  large_score_dif
# 3               False    0                0
# 4               False    0                0
# 5               False    0                0
# 9               False    0                0
# 10              False    0                0
# ...               ...  ...              ...
# 280779          False    1                1
# 280780          False    1                1
# 280784          False    0                1
# 280785          False    0                1
# 280786          False    0                1
#
# [92050 rows x 23 columns]

# %%
df_with_at_bat_sequence_ordered.columns
# Out:
# Index(['game_date', 'player_name', 'pitcher', 'batter', 'stand', 'pitch_type',
#        'pitch_name', 'description', 'zone', 'balls', 'strikes', 'inning',
#        'pitch_number', 'home_score', 'away_score', 'outs_when_up', 'events',
#        'sequence_id', 'new_at_bat', 'times_faced', 'extra_base_hit', 'XBH',
#        'large_score_dif'],
#       dtype='object')

# %%
df_with_at_bat_sequence_ordered =df_with_at_bat_sequence_ordered.drop(columns=['events', 'new_at_bat', 'extra_base_hit', 'home_score', 'away_score', 'game_date', 'inning'])

# %%
df_with_at_bat_sequence_ordered['sequence_id'].unique()
# Out:
# array(['1-1_SL_ball|1-0_FF_foul|0-0_FF_ball',
#        '2-1_FF_called_strike|1-1_SL_ball|1-0_FF_foul',
#        '2-2_SL_ball|2-1_FF_called_strike|1-1_SL_ball', ...,
#        '2-0_SI_swinging_strike|1-0_FF_ball|0-0_FF_ball',
#        '2-1_SI_called_strike|2-0_SI_swinging_strike|1-0_FF_ball',
#        '2-2_FC_ball|2-1_SI_called_strike|2-0_SI_swinging_strike'],
#       dtype=object)
